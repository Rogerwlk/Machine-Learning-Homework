# %%
from matplotlib import pyplot as plt

y = [0.051128,0.029241,0.020176,0.01565,0.013448,0.012145,0.011411,0.01068,0.010485,0.009925,0.009676,0.009298,0.009047,0.008878,0.008505,0.008473,0.008145,0.008202,0.008249,0.007929,0.007706,0.007502,0.0074,0.00725,0.007128,0.006964,0.006983,0.006744,0.006944,0.006861,0.006596,0.006691,0.006593,0.006455,0.006377,0.006284,0.006309,0.006173,0.006244,0.006391,0.006174,0.005974,0.005817,0.005952,0.005771,0.005734,0.005865,0.005704,0.005614,0.005765]
x = [102,202,302,402,502,602,698,799,902,997,1102,1202,1300,1401,1502,1602,1702,1802,1898,2000,2096,2202,2302,2402,2502,2602,2701,2802,2898,2998,3102,3202,3299,3398,3502,3602,3702,3802,3902,3996,4102,4202,4302,4402,4495,4601,4697,4802,4902,5002]
plt.plot(x,y)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.axis([0,5000,0,0.06])
plt.savefig("c.jpg")

# %%
plt.plot(x,y)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.axis([0,5000,0,0.06])
plt.savefig("c.jpg")
