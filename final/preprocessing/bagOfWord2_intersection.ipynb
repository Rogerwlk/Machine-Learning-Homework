# %%
import glob, re, nltk
from collections import Counter
from collections import defaultdict
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import *
from nltk import word_tokenize
from math import log
from math import sqrt
from nltk.corpus import stopwords
import numpy as np
nltk.download("punkt")
nltk.download("wordnet")
nltk.download('stopwords')
# haven't done spell checking
# Out:
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
word_doc = defaultdict(Counter)
doc_word = defaultdict(Counter)
#read stop words
stop_words = set()
f = open('stops.txt', 'r')
for line in f:
    stop_words.add(line.strip())
f.close()
for w in stopwords.words('english'):
    stop_words.add(w)
print(len(stop_words), stop_words)
# Out:
# 621 {'known', 'clearly', 'like', 'specify', 'maybe', 'okay', '}', 'where', 'anywhere', 'knows', 'regards', "shan't", 'for', 'x', 'about', 'gives', 'all', 'n', '.', 'next', 'somewhere', 'little', 'noone', 'would', 'soon', 'un', 'looks', 'becoming', 'somehow', 'below', 'thorough', 'none', 'wasn', 'wherever', 'inner', 'unlikely', "we're", 'whether', 'on', 'better', 'awfully', 'use', 'nothing', 'example', "there's", 'am', 'sub', '=', 'thats', 'wish', 'ok', 'regarding', 'thoroughly', '|', 'whither', 'hasn', 'indicates', 'and', 'specified', 'nowhere', 'aside', 'associated', 'still', 'que', '~', 'without', 'com', 'now', 'or', 'appear', 'him', 'taken', 'ask', 'et', 'necessary', 'value', 'those', '$', 'r', 'hi', 'everybody', 'sensible', 'could', 'only', 'themselves', 'to', 'contain', 'placed', 'each', 'thank', 'anyway', 'beforehand', 'theirs', 'toward', 'their', 'come', 'this', 'we', 'amongst', 'furthermore', 'hers', 'see', '_', 'got', 'least', 'been', 'changes', 'otherwise', 'therein', 'same', 'cause', 'shouldn', 'among', 'tried', 'often', 'himself', 'former', 'itself', 'might', 'hereafter', 'probably', 'just', 'herein', "won't", 've', 'mustn', 'j', 'given', 'already', 'mainly', 'q', 'qv', 'how', 'someone', '^', 'couldn', 'oh', 'she', 'th', '/', 'came', 'other', 'unless', 'whoever', 'help', 'apart', 'because', 'ie', 'seeing', 'appreciate', 'sometime', 'howbeit', "i'll", 'ours', 'u', 'best', 'said', 'any', '-', "they'd", 'you', 'ma', 'wants', "wouldn't", "haven't", "t's", 'quite', 'haven', 'useful', 'rather', '*', 'course', 'look', 'against', "couldn't", 'l', 'uucp', '%', "it's", 'keeps', 'using', 'most', "needn't", 'became', 'together', 'his', "she's", 'since', 'say', 'thereafter', 'else', "doesn't", '+', "ain't", 'across', 'selves', '>', 'insofar', "let's", 'another', 'rd', 'inasmuch', 'were', 'everywhere', 'anybody', 'our', 'either', 'following', "that'll", 'a', 'down', 'vs', "we'd", 'consider', "where's", 'did', "you'll", 'does', '@', 'around', 'novel', 'greetings', 'doesn', 'z', 'anything', 'thence', 'take', 'except', 'normally', 'didn', 'becomes', '!', 'afterwards', 'ltd', 'seem', 'several', 'mightn', 'consequently', 'towards', 'p', 'kept', 'despite', 'welcome', 'anyone', 'whereafter', 'yourselves', 'saying', 'into', 'indeed', 'allow', 'hopefully', 'than', 'per', 'seemed', 'm', 'right', 'gets', 'shall', 'exactly', 'even', 'ex', 'beside', 'perhaps', 'after', 'that', 'can', 'until', 'hardly', 'hereupon', 'considering', 'going', 'eg', 'away', "shouldn't", 'edu', 'gone', 'upon', 'please', 'f', 'such', 'own', 'immediate', 'thanks', 'causes', 'cannot', 'nevertheless', 'herself', 'whom', 'again', 'tell', 'truly', 'downwards', 'usually', "isn't", 'many', 'want', 'believe', 'k', "we've", 'lest', 'll', 'appropriate', 'needs', "they'll", 'indicated', 'what', 'presumably', 'everything', 'new', 'concerning', 's', 'keep', 'then', 'possible', 'her', 'know', 'namely', 'whereas', 'accordingly', 'off', 'last', 'through', 'enough', 'in', 'may', 'out', 'lately', 'goes', 'contains', 'currently', 'must', 'as', 'different', 'do', "hadn't", 'try', 'hereby', 'certain', 'from', 'behind', 'b', "mustn't", 'during', 'likely', "you're", 'shan', 'don', 'think', 'whereby', 'wherein', 'should', 'every', 'when', 'over', 'need', 'always', 'seriously', 'too', 'not', 'seen', 'whereupon', 'ignored', 'others', 'some', '#', ')', 'well', 'yet', 'saw', "you'd", 'd', 'fifth', 'them', 'twice', "it'd", 'plus', "that's", 'which', 'e', 'mean', 'mostly', 'at', ']', "here's", 'few', 'i', 'unfortunately', 'uses', 'here', 'name', 'never', "weren't", 'happens', 'alone', 'also', 'are', 'however', 'h', 'able', "you've", 'instead', 'with', 'they', 'self', "'", 'be', 'described', 'under', "c'mon", 'formerly', 'but', 'seems', 'done', 'definitely', "i'm", 'throughout', 'sure', 'elsewhere', 'why', ',', 'become', 'more', 'an', "should've", '"', 'whose', 'containing', 'corresponding', 'above', 'though', '{', 'therefore', 'ones', 'reasonably', 'weren', '&', 'forth', 'ourselves', 'first', 'h ...

# %%
def df(term):
    return len(word_doc[term])

def idf(term):
    return log(len(doc_word) / df(term), 10)

def prefixReplace(match):
    prefix, stem = match.group(1), match.group(2)
    temp = prefix + stem
    if not stem in stop_words:
        temp += ' ' + stem
    return temp

def hyphenReplace(match):
    temp = match.group()
    li = temp.split('-')
    temp = temp.replace('-', '')
    for item in li:
        if not item in stop_words:
            temp += ' ' + item
    return temp

def writeToFile(index_table):
    # write to output
    output_file = open('single_term_idx_table.txt', 'w')
    for key in sorted(index_table.keys()):
        output_file.write(' '.join(str(x) for x in key)+' '+str(index_table[key])+'\n')
    output_file.close()

def createIndexTable(input_path, doc_type):
    vocab = set()
    # format input_path to ./input_path/
    if input_path[0] == '/':
        input_path = '.' + input_path
    if input_path[-1] != '/':
        input_path += '/'
    wnl = WordNetLemmatizer()
    stemmer = PorterStemmer()
    files = glob.glob(input_path+'*') # grab all the files under path
    print(len(files))
    get_num = re.compile(r'(\d+)')
    p_prefix = re.compile(r'\b(a|an|ante|anti|auto|circum|co|com|con|contra|contro|de|dis|en|em|ex|extra|fore|hetero|homo|homeo|hyper|il|im|in|ir|inter|intra|intro|macro|micro|mid|mis|mono|non|omni|over|post|pre|pro|re|semi|sub|super|sym|syn|trans|tri|un|under|uni)-([a-z])+\b', re.I)
    p_hyphen = re.compile(r'\b(\w+-)+\w+\b')
    
    for file in files:
        f = open(file, 'r')
        docno = (doc_type,int(get_num.search(file).group(1)))
        for line in f:
            line = line.strip()
            line = line.lower()
            # expand stem with hyphen prefix
            line = p_prefix.sub(prefixReplace, line)
            # expand hyphenated word
            line = p_hyphen.sub(hyphenReplace, line)
            line = line.replace(':', ' ')
            line = line.replace('\'s', '')
            line = line.replace(',', ' ')
            line = line.replace('.', ' ')
            li = word_tokenize(line)
            li = [wnl.lemmatize(x) for x in li]
            li = [stemmer.stem(x) for x in li]
            for word in li:
                if not word in stop_words:
                    # build single term idx
                    word_doc[word][docno] += 1
                    doc_word[docno][word] += 1
                    vocab.add(word)
    return vocab

# %%
vocab_train_description = createIndexTable('../data/descriptions_train', 'train')
vocab_test_description = createIndexTable('../data/descriptions_test', 'test')
vocab_list = sorted(vocab_train_description.intersection(vocab_test_description))
print('num of vocab:', len(vocab_list))
train_d = []
test_d = []
for i in range(10000):
    tup = ('train', i)
    train_d.append([doc_word[tup][w] * idf(w) for w in vocab_list])
for i in range(2000):
    tup = ('test', i)
    test_d.append([doc_word[tup][w] * idf(w) for w in vocab_list])
np.save('bagOfWord_intersection_train_description.npy', train_d)
np.save('bagOfWord_intersection_test_description.npy', test_d)

print(len(train_d), len(train_d[0]))
print(len(test_d), len(test_d[0]))

print('finish description bag of word with idf')
# Out:
# 10000
# 2000
# num of vocab: 2776
# 10000 2776
# 2000 2776
# finish description bag of word with idf

# %%
train_d_no_idf = []
test_d_no_idf = []
for i in range(10000):
    tup = ('train', i)
    train_d_no_idf.append([doc_word[tup][w] for w in vocab_list])
for i in range(2000):
    tup = ('test', i)
    test_d_no_idf.append([doc_word[tup][w] for w in vocab_list])
np.save('bagOfWord_intersection_train_description_no_idf.npy', train_d_no_idf)
np.save('bagOfWord_intersection_test_description_no_idf.npy', test_d_no_idf)

print(len(train_d_no_idf), len(train_d_no_idf[0]))
print(len(test_d_no_idf), len(test_d_no_idf[0]))

print('finish description bag of word without idf')
# Out:
# 10000 2776
# 2000 2776
# finish description bag of word without idf

# %%
word_doc.clear()
doc_word.clear()

# %%
vocab_train_tag = createIndexTable('../data/tags_train', 'train')
vocab_test_tag = createIndexTable('../data/tags_test', 'test')
vocab_list = sorted(vocab_train_tag.intersection(vocab_test_tag))
print('num of vocab:', len(vocab_list))
train_t = []
test_t = []
for i in range(10000):
    tup = ('train', i)
    train_t.append([doc_word[tup][w] * idf(w) for w in vocab_list])
for i in range(2000):
    tup = ('test', i)
    test_t.append([doc_word[tup][w] * idf(w) for w in vocab_list])

train_t = np.array(train_t)
test_t = np.array(test_t)
np.save('bagOfWord_intersection_train_tag.npy', train_t)
np.save('bagOfWord_intersection_test_tag.npy', test_t)

print(len(train_t), len(train_t[0]))
print(len(test_t), len(test_t[0]))

print('finish tag bag of word with idf')
# Out:
# 10000
# 2000
# num of vocab: 102
# 10000 102
# 2000 102
# finish tag bag of word with idf

# %%
train_t_no_idf = []
test_t_no_idf = []
for i in range(10000):
    tup = ('train', i)
    train_t_no_idf.append([doc_word[tup][w] for w in vocab_list])
for i in range(2000):
    tup = ('test', i)
    test_t_no_idf.append([doc_word[tup][w] for w in vocab_list])

train_t_no_idf = np.array(train_t_no_idf)
test_t_no_idf = np.array(test_t_no_idf)
np.save('bagOfWord_intersection_train_tag_no_idf.npy', train_t_no_idf)
np.save('bagOfWord_intersection_test_tag_no_idf.npy', test_t_no_idf)

print(len(train_t_no_idf), len(train_t_no_idf[0]))
print(len(test_t_no_idf), len(test_t_no_idf[0]))

print('finish tag bag of word without idf')
# Out:
# 10000 102
# 2000 102
# finish tag bag of word without idf

# %%
word_doc.clear()
doc_word.clear()

# %%
def empty_vec(data):
    for i in range(len(data)):
        if len(set(data[i])) == 1:
            print(i, end=' ')

print('\ntrain description empty vec')
empty_vec(train_d)
print('\ntest description empty vec')
empty_vec(test_d)
print('\ntrain tag vec')
empty_vec(train_t)
print('\ntest tag vec')
empty_vec(test_t)
print()
# Out:
# train description empty vec
#
# test description empty vec
#
# train tag vec
# 12 46 656 677 1312 1337 1364 1374 1410 1547 1615 1807 1831 2191 2253 2286 2375 2407 2772 2865 2911 3068 3327 3345 3388 3434 3437 3491 3554 3602 3668 3778 3861 3913 4089 4152 4166 4386 4417 4484 4633 4726 5054 5165 5191 5363 5513 5722 5805 5824 6094 6522 6678 6715 6776 6832 6966 7192 7318 7410 7849 7888 7973 8031 8080 8122 8329 8371 8447 8606 8649 8713 8732 8835 9103 9142 9305 9491 9566 9620 9713 9809 9911 9933
# test tag vec
# 452 607 763 784 860 1027 1030 1033 1059 1208 1340 1421 1437 1475 1574 1648

# %%
word_doc.clear()
doc_word.clear()
createIndexTable('../data/descriptions_train', 'train')
createIndexTable('../data/descriptions_test', 'test')
word_freq = Counter()
for w in word_doc.keys():
    word_freq[w] += sum(word_doc[w].values())
print(len(word_freq))
print(word_freq.most_common()[-5000:])
# Out:
# 10000
# 2000
# 7077
# [('gun', 7), ('shaggi', 7), ('jam', 7), ('mango', 7), ('stylish', 7), ('bone', 7), ('religi', 7), ('vine', 7), ('backseat', 7), ('showcas', 7), ('join', 7), ('mural', 7), ('raincoat', 7), ('assembl', 7), ('forehead', 7), ('bidet', 7), ('wok', 7), ('nearli', 7), ('inflat', 7), ('goali', 7), ('marsh', 7), ('portabl', 7), ('backward', 7), ('sailor', 7), ('current', 7), ('lite', 7), ('broadway', 7), ('secur', 7), ('safe', 7), ('refridger', 7), ('pilot', 7), ('tortilla', 7), ('overturn', 7), ('vertic', 7), ('stew', 7), ('circu', 7), ('morn', 7), ('fuzzi', 7), ('beani', 7), ('rundown', 7), ('fourth', 7), ('exot', 7), ('rooftop', 7), ('favorit', 7), ('wakeboard', 7), ('cloudless', 7), ('quaint', 7), ('forc', 7), ('weigh', 7), ('syrup', 7), ('runner', 7), ('congreg', 7), ('conveyor', 7), ('motel', 7), ('hairdryer', 7), ('wrestler', 7), ('hiker', 7), ('real', 7), ('focus', 7), ('parakeet', 7), ('dial', 7), ('shutter', 7), ('puffi', 7), ('pedal', 7), ('bad', 7), ('offici', 7), ('launch', 7), ('hundr', 7), ('rower', 7), ('fat', 7), ('knack', 7), ('height', 7), ('cube', 7), ('crazi', 7), ('parallel', 7), ('perfect', 7), ('instruct', 7), ('mr', 7), ('medal', 7), ('twilight', 7), ('feel', 7), ('plantain', 7), ('photoshop', 7), ('wheeli', 7), ('hangar', 7), ('rabbit', 7), ('chat', 7), ('cane', 7), ('personnel', 7), ('paul', 7), ('die', 7), ('radish', 7), ('halfpip', 7), ('alien', 7), ('templ', 7), ('aquarium', 7), ('frisb', 7), ('summer', 7), ('twig', 7), ('salon', 7), ('tournament', 7), ('pamphlet', 7), ('pooh', 7), ('rhino', 7), ('sheer', 7), ('particip', 6), ('whit', 6), ('forag', 6), ('effect', 6), ('cobbl', 6), ('studio', 6), ('sandal', 6), ('juicer', 6), ('resembl', 6), ('serf', 6), ('investig', 6), ('filter', 6), ('consum', 6), ('ancient', 6), ('basic', 6), ('quickli', 6), ('shed', 6), ('nail', 6), ('mosaic', 6), ('nokia', 6), ('univers', 6), ('slant', 6), ('fireman', 6), ('icebox', 6), ('lazi', 6), ('trashcan', 6), ('tripod', 6), ('overal', 6), ('strong', 6), ('citru', 6), ('livingroom', 6), ('accid', 6), ('lung', 6), ('eagl', 6), ('skylight', 6), ('stormi', 6), ('access', 6), ('snowcov', 6), ('nativ', 6), ('hall', 6), ('mascot', 6), ('creek', 6), ('butterfli', 6), ('band', 6), ('lavend', 6), ('confer', 6), ('futon', 6), ('amidst', 6), ('mate', 6), ('brows', 6), ('simul', 6), ('victorian', 6), ('compani', 6), ('cock', 6), ('hut', 6), ('glider', 6), ('complex', 6), ('bunt', 6), ('oak', 6), ('yummi', 6), ('machineri', 6), ('perspect', 6), ('din', 6), ('watermelon', 6), ('eiffel', 6), ('bmw', 6), ('mass', 6), ('convert', 6), ('ici', 6), ('5', 6), ('tball', 6), ('patron', 6), ('dinosaur', 6), ('scape', 6), ('bud', 6), ('neath', 6), ('preform', 6), ('leafless', 6), ('25', 6), ('erect', 6), ('toilett', 6), ('highchair', 6), ('convey', 6), ('retail', 6), ('lost', 6), ('barbecu', 6), ('dude', 6), ('instrument', 6), ('maneuv', 6), ('tend', 6), ('sidecar', 6), ('destin', 6), ('italian', 6), ('replac', 6), ('centerpiec', 6), ('plier', 6), ('notepad', 6), ('torn', 6), ('cozi', 6), ('patriot', 6), ('rollerblad', 6), ('visitor', 6), ('coconut', 6), ('prairi', 6), ('bubbl', 6), ('cel', 6), ('queen', 6), ('grin', 6), ('playground', 6), ('teddybear', 6), ('scrub', 6), ('similar', 6), ('goofi', 6), ('stomach', 6), ('cemeteri', 6), ('belong', 6), ('terrac', 6), ('alert', 6), ('bandana', 6), ('stovetop', 6), ('expir', 6), ('tinfoil', 6), ('chalk', 6), ('grand', 6), ('brussel', 6), ('lobster', 6), ('blazer', 6), ('20', 6), ('column', 6), ('cheesecak', 6), ('almond', 6), ('bounc', 6), ('horizon', 6), ('assist', 6), ('plumb', 6), ('peck', 6), ('binder', 6), ('overview', 6), ('contest', 6), ('central', 6), ('fasten', 6), ('occupi', 6), ('teal', 6), ('refere', 6), ('support', 6), ('teammat', 6), ('minut', 6), ('iwth', 6), ('shack', 6), ('linen', 6), ('dim', 6), ('swimmer', 6), ('mexican', 6), ('ford', 6), ('western', 6), ('peacock', 6), ('headset', 6), ('trio', 6), ('sleepi', 6), ('hanger', 6), ('hurdl', 6), ('creativ', 6), ('upscal', 6), ('dalmatian', 6), ( ...

# %%
freq_list = list(word_freq.values())
for i in range(1, 11):
    print('word appear '+str(i)+' times:', freq_list.count(i))
# Out:
# word appear 1 times: 2713
# word appear 2 times: 909
# word appear 3 times: 457
# word appear 4 times: 396
# word appear 5 times: 233
# word appear 6 times: 187
# word appear 7 times: 126
# word appear 8 times: 126
# word appear 9 times: 102
# word appear 10 times: 78
